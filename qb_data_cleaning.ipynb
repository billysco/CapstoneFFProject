# %%
import pandas as pd
import numpy as np

# %%
# importing draft data
draft_2022 = pd.read_csv('draft_data/2022.csv')
draft_2021 = pd.read_csv('draft_data/2021.csv')
draft_2020 = pd.read_csv('draft_data/2020.csv')
draft_2019 = pd.read_csv('draft_data/2019.csv')
draft_2018 = pd.read_csv('draft_data/2018.csv')
draft_2017 = pd.read_csv('draft_data/2017.csv')
draft_2016 = pd.read_csv('draft_data/2016.csv')
draft_2015 = pd.read_csv('draft_data/2015.csv')
draft_2014 = pd.read_csv('draft_data/2014.csv')
draft_2013 = pd.read_csv('draft_data/2013.csv')
draft_2012 = pd.read_csv('draft_data/2012.csv')
draft_2011 = pd.read_csv('draft_data/2011.csv')
draft_2010 = pd.read_csv('draft_data/2010.csv')
draft_2009 = pd.read_csv('draft_data/2009.csv')
draft_2008 = pd.read_csv('draft_data/2008.csv')
draft_2007 = pd.read_csv('draft_data/2007.csv')
draft_2006 = pd.read_csv('draft_data/2006.csv')
draft_2005 = pd.read_csv('draft_data/2005.csv')
draft_2004 = pd.read_csv('draft_data/2004.csv')
draft_2003 = pd.read_csv('draft_data/2003.csv')
draft_2002 = pd.read_csv('draft_data/2002.csv')
draft_2001 = pd.read_csv('draft_data/2001.csv')
draft_2000 = pd.read_csv('draft_data/2000.csv')
draft_1999 = pd.read_csv('draft_data/1999.csv')
draft_1998 = pd.read_csv('draft_data/1998.csv')
draft_1997 = pd.read_csv('draft_data/1997.csv')
draft_1996 = pd.read_csv('draft_data/1996.csv')
draft_1995 = pd.read_csv('draft_data/1995.csv')
draft_1994 = pd.read_csv('draft_data/1994.csv')
draft_1993 = pd.read_csv('draft_data/1993.csv')

# adding a year column to draft dfs
draft_2022['Year'] = 2022
draft_2021['Year'] = 2021
draft_2020['Year'] = 2020
draft_2019['Year'] = 2019
draft_2018['Year'] = 2018
draft_2017['Year'] = 2017
draft_2016['Year'] = 2016
draft_2015['Year'] = 2015
draft_2014['Year'] = 2014
draft_2013['Year'] = 2013
draft_2012['Year'] = 2012
draft_2011['Year'] = 2011
draft_2010['Year'] = 2010
draft_2009['Year'] = 2009
draft_2008['Year'] = 2008
draft_2007['Year'] = 2007
draft_2006['Year'] = 2006
draft_2005['Year'] = 2005
draft_2004['Year'] = 2004
draft_2003['Year'] = 2003
draft_2002['Year'] = 2002
draft_2001['Year'] = 2001
draft_2000['Year'] = 2000
draft_1999['Year'] = 1999
draft_1998['Year'] = 1998
draft_1997['Year'] = 1997
draft_1996['Year'] = 1996
draft_1995['Year'] = 1995
draft_1994['Year'] = 1994
draft_1993['Year'] = 1993

# read in combine data
combine_2022 = pd.read_csv('combine_data/2022.csv')
combine_2021 = pd.read_csv('combine_data/2021.csv')
combine_2020 = pd.read_csv('combine_data/2020.csv')
combine_2019 = pd.read_csv('combine_data/2019.csv')
combine_2018 = pd.read_csv('combine_data/2018.csv')
combine_2017 = pd.read_csv('combine_data/2017.csv')
combine_2016 = pd.read_csv('combine_data/2016.csv')
combine_2015 = pd.read_csv('combine_data/2015.csv')
combine_2014 = pd.read_csv('combine_data/2014.csv')
combine_2013 = pd.read_csv('combine_data/2013.csv')
combine_2012 = pd.read_csv('combine_data/2012.csv')
combine_2011 = pd.read_csv('combine_data/2011.csv')
combine_2010 = pd.read_csv('combine_data/2010.csv')
combine_2009 = pd.read_csv('combine_data/2009.csv')
combine_2008 = pd.read_csv('combine_data/2008.csv')
combine_2007 = pd.read_csv('combine_data/2007.csv')
combine_2006 = pd.read_csv('combine_data/2006.csv')
combine_2005 = pd.read_csv('combine_data/2005.csv')
combine_2004 = pd.read_csv('combine_data/2004.csv')
combine_2003 = pd.read_csv('combine_data/2003.csv')
combine_2002 = pd.read_csv('combine_data/2002.csv')
combine_2001 = pd.read_csv('combine_data/2001.csv')
combine_2000 = pd.read_csv('combine_data/2000.csv')
combine_1999 = pd.read_csv('combine_results/1999.csv')
combine_1998 = pd.read_csv('combine_results/1998.csv')
combine_1997 = pd.read_csv('combine_results/1997.csv')
combine_1996 = pd.read_csv('combine_results/1996.csv')
combine_1995 = pd.read_csv('combine_results/1995.csv')
combine_1994 = pd.read_csv('combine_results/1994.csv')
combine_1993 = pd.read_csv('combine_results/1993.csv')

# adding a year to the combine data
combine_2022['Year'] = 2022
combine_2021['Year'] = 2021
combine_2020['Year'] = 2020
combine_2019['Year'] = 2019
combine_2018['Year'] = 2018
combine_2017['Year'] = 2017
combine_2016['Year'] = 2016
combine_2015['Year'] = 2015
combine_2014['Year'] = 2014
combine_2013['Year'] = 2013
combine_2012['Year'] = 2012
combine_2011['Year'] = 2011
combine_2010['Year'] = 2010
combine_2009['Year'] = 2009
combine_2008['Year'] = 2008
combine_2007['Year'] = 2007
combine_2006['Year'] = 2006
combine_2005['Year'] = 2005
combine_2004['Year'] = 2004
combine_2003['Year'] = 2003
combine_2002['Year'] = 2002
combine_2001['Year'] = 2001
combine_2000['Year'] = 2000
combine_1999['Year'] = 1999
combine_1998['Year'] = 1998
combine_1997['Year'] = 1997
combine_1996['Year'] = 1996
combine_1995['Year'] = 1995
combine_1994['Year'] = 1994
combine_1993['Year'] = 1993

# read in rushing data
passing_2022 = pd.read_csv('passing/2022.csv')
passing_2021 = pd.read_csv('passing/2021.csv')
passing_2020 = pd.read_csv('passing/2020.csv')
passing_2019 = pd.read_csv('passing/2019.csv')
passing_2018 = pd.read_csv('passing/2018.csv')
passing_2017 = pd.read_csv('passing/2017.csv')
passing_2016 = pd.read_csv('passing/2016.csv')
passing_2015 = pd.read_csv('passing/2015.csv')
passing_2014 = pd.read_csv('passing/2014.csv')
passing_2013 = pd.read_csv('passing/2013.csv')
passing_2012 = pd.read_csv('passing/2012.csv')
passing_2011 = pd.read_csv('passing/2011.csv')
passing_2010 = pd.read_csv('passing/2010.csv')
passing_2009 = pd.read_csv('passing/2009.csv')
passing_2008 = pd.read_csv('passing/2008.csv')
passing_2007 = pd.read_csv('passing/2007.csv')
passing_2006 = pd.read_csv('passing/2006.csv')
passing_2005 = pd.read_csv('passing/2005.csv')
passing_2004 = pd.read_csv('passing/2004.csv')
passing_2003 = pd.read_csv('passing/2003.csv')
passing_2002 = pd.read_csv('passing/2002.csv')
passing_2001 = pd.read_csv('passing/2001.csv')
passing_2000 = pd.read_csv('passing/2000.csv')
passing_1999 = pd.read_csv('passing/1999.csv')
passing_1998 = pd.read_csv('passing/1998.csv')
passing_1997 = pd.read_csv('passing/1997.csv')
passing_1996 = pd.read_csv('passing/1996.csv')
passing_1995 = pd.read_csv('passing/1995.csv')
passing_1994 = pd.read_csv('passing/1994.csv')
passing_1993 = pd.read_csv('passing/1993.csv')

# add a year column to receiving
passing_2022['Year'] = 2022
passing_2021['Year'] = 2021
passing_2020['Year'] = 2020
passing_2019['Year'] = 2019
passing_2018['Year'] = 2018
passing_2017['Year'] = 2017
passing_2016['Year'] = 2016
passing_2015['Year'] = 2015
passing_2014['Year'] = 2014
passing_2013['Year'] = 2013
passing_2012['Year'] = 2012
passing_2011['Year'] = 2011
passing_2010['Year'] = 2010
passing_2009['Year'] = 2009
passing_2008['Year'] = 2008
passing_2007['Year'] = 2007
passing_2006['Year'] = 2006
passing_2005['Year'] = 2005
passing_2004['Year'] = 2004
passing_2003['Year'] = 2003
passing_2002['Year'] = 2002
passing_2001['Year'] = 2001
passing_2000['Year'] = 2000
passing_1999['Year'] = 1999
passing_1998['Year'] = 1998
passing_1997['Year'] = 1997
passing_1996['Year'] = 1996
passing_1995['Year'] = 1995
passing_1994['Year'] = 1994
passing_1993['Year'] = 1993

# %%
passing_2021.head()
# Out:
#    Rk           Player            School      Conf   G  Completions  Attempts  \
# 0   1   Grayson McCall  Coastal Carolina  Sun Belt  11          176       241
# 1   2      C.J. Stroud        Ohio State   Big Ten  12          317       441
# 2   3  Stetson Bennett           Georgia       SEC  14          185       287
# 3   4    Hendon Hooker         Tennessee       SEC  13          206       303
# 4   5    Dylan Hopkins               UAB      CUSA  13          155       235
#
#    CompletionPCT  PassYds  YardsPerAttempt  AdjustedYardsPerAttempt  \
# 0           73.0     2873             11.9                     13.6
# 1           71.9     4435             10.1                     11.4
# 2           64.5     2862             10.0                     10.9
# 3           68.0     2945              9.7                     11.3
# 4           66.0     2274              9.7                      9.9
#
#    PassingTDs  Int  EfficiencyRtg  RushAtt  RushYds  RushAvg  RushTD  Year
# ...

# %%
def clean_combine(combine_full, position):
    combine_full = combine_full[combine_full['Position']==f'{position}']
    combine_full = combine_full[combine_full['Year'].notna()].copy()
    combine_full = combine_full.reset_index(drop=True)
    combine_full['Year'] = combine_full['Year'].astype(int)
    combine_full['Year'] = combine_full['Year'].astype(str)
    combine_full['Player'] = combine_full['Player'].str.lower()
    combine_full['Drafted'] = combine_full['Drafted'].str.split("/")
    combine_full['Round'] = combine_full['Drafted'].str[1]
    combine_full['Pick'] = combine_full['Drafted'].str[2]
    combine_full['Pick'] = combine_full['Pick'].str.replace("th pick","")
    combine_full['Pick'] = combine_full['Pick'].str.replace("rd pick","")
    combine_full['Pick'] = combine_full['Pick'].str.replace("nd pick","")
    combine_full['Pick'] = combine_full['Pick'].str.replace("st pick","")

    combine_full['Round'] = combine_full['Round'].str.replace("th","")
    combine_full['Round'] = combine_full['Round'].str.replace("rd","")
    combine_full['Round'] = combine_full['Round'].str.replace("nd","")
    combine_full['Round'] = combine_full['Round'].str.replace("st","")

    combine_full['Pick'] = combine_full['Pick'].astype('int32')
    combine_full['Round'] = combine_full['Round'].astype('int32')
    # converting height to inches
    combine_full = combine_full[combine_full['Height'].notnull()]
    combine_full['Height'] = combine_full['Height'].str.split("-")
    combine_full['Feet'] = combine_full['Height'].str[0]
    combine_full['Inches'] = combine_full['Height'].str[1]
    combine_full['Feet'] = combine_full['Feet'].astype('int')
    combine_full['Inches'] = combine_full['Inches'].astype('int')
    combine_full['Height (in)'] = combine_full['Feet']*12 + combine_full['Inches']

    combine_full = combine_full.drop(columns=['College', 'Height', 'Bench', 'Broad Jump', 'Drafted', 'Feet', 'Inches'])
    
    return combine_full

# %%
def clean_combine90s(combine_full, position):
    combine_full = combine_full[combine_full['POS']==f'{position}']
    combine_full = combine_full[combine_full['Year'].notna()].copy()
    combine_full = combine_full.reset_index(drop=True)
    # converting to an integer to remove decimal then to string to concatenate with other fields
    combine_full['Year'] = combine_full['Year'].astype(int)
    combine_full['Year'] = combine_full['Year'].astype(str)
    combine_full['Name'] = combine_full['Name'].str.lower()
    
    combine_full = combine_full.drop(columns=['Hand Size (in)', 'Arm Length (in)', 'Bench Press', '60Yd Shuttle', 'Wonderlic', 'Broad Jump (in)'])
    cols = combine_full.columns.tolist()
    cols = [cols[1]] + [cols[3]] + [cols[2]] + cols[5:8] + [cols[-1]]+ [cols[-2]] + [cols[0]] + [cols[4]]
    combine_full = combine_full[cols]
    combine_full.columns = ['Player', 'Position', 'School', 'Weight', '40 Time', 'Vertical Jump', '3 Cone', 'Shuttle', 'Year', 'Height (in)']
    combine_full['Year'] = combine_full['Year'].astype(str)
    combine_full['PK'] = combine_full['Player'].str.lower() + "+" + combine_full['Year']
    combine_full['Year'] = combine_full['Year'].astype(int)
    return combine_full

# %%
pass_stats = pd.concat([passing_2022, passing_2021, passing_2020, passing_2019, passing_2018, passing_2017, passing_2016, passing_2015, passing_2014, passing_2013, passing_2012, passing_2011, passing_2010, passing_2009, passing_2008,
                          passing_2007, passing_2006, passing_2005, passing_2004, passing_2003, passing_2002, passing_2001, passing_2000, passing_1999, passing_1998, passing_1997, 
                        passing_1996, passing_1995, passing_1994, passing_1993])
pass_stats
# Out:
#     Rk          Player                School      Conf   G  Completions  \
# 0    1   Hendon Hooker             Tennessee       SEC  11          229
# 1    2    Todd Centeio         James Madison  Sun Belt  10          181
# 2    3     C.J. Stroud            Ohio State   Big Ten  12          235
# 3    4   Kurtis Rourke                  Ohio       MAC  11          244
# 4    5  Grayson McCall      Coastal Carolina  Sun Belt  10          197
# ..  ..             ...                   ...       ...  ..          ...
# 79  80    Jamie Howard                   LSU       SEC  10          106
# 80  81   Craig Randall                Tulane       Ind  12          151
# 81  82  Chuck Clements               Houston       SWC   9          124
# 82  83     Danny Smith            Miami (OH)       MAC  11           92
# 83  84   Kevin Bentley  Southern Mississippi       Ind  11           77
#
#     Attempts  CompletionPCT  PassYds  YardsPerAttempt  \
# ...

# %%
pass_stats['AdjustedYds'] = pass_stats['AdjustedYardsPerAttempt']*pass_stats['Attempts']

# %%
pass_stats.head()
# Out:
#    Rk          Player            School      Conf   G  Completions  Attempts  \
# 0   1   Hendon Hooker         Tennessee       SEC  11          229       329
# 1   2    Todd Centeio     James Madison  Sun Belt  10          181       284
# 2   3     C.J. Stroud        Ohio State   Big Ten  12          235       355
# 3   4   Kurtis Rourke              Ohio       MAC  11          244       353
# 4   5  Grayson McCall  Coastal Carolina  Sun Belt  10          197       285
#
#    CompletionPCT  PassYds  YardsPerAttempt  AdjustedYardsPerAttempt  \
# 0           69.6     3135              9.5                     10.9
# 1           63.7     2697              9.5                     10.5
# 2           66.2     3340              9.4                     10.7
# 3           69.1     3257              9.2                     10.1
# 4           69.1     2633              9.2                     10.6
#
#    PassingTDs  Int  EfficiencyRtg  RushAtt  RushYds  RushAvg  RushTD  Year  \
# ...

# %%
# standardizing player names and adding a primary key and space for a last_year column
pass_stats['Player'] = pass_stats['Player'].str.lower()
pass_stats['PK1'] = pass_stats['Player']+"+"+pass_stats['School']
pass_stats['Last_Year'] = np.nan

# %%
def get_ly(pk):
    """Function to determine the last year a player played in college"""
    a = pass_stats.loc[pass_stats['PK1']==f'{pk}']
    b = max(a['Year'])
    return b

# %%
# creating a list for use in the next step
pk_list = []
for index, row in pass_stats.iterrows():
    pk_list.append(row['PK1'])
    
pk_list[:5]
# Out:
# ['hendon hooker+Tennessee',
#  'todd centeio+James Madison',
#  'c.j. stroud+Ohio State',
#  'kurtis rourke+Ohio',
#  'grayson mccall+Coastal Carolina']

# %%
# creating a list of the last year each player played 
year_list = []
for x in pk_list:
    year_list.append(get_ly(f"{x}"))

year_list[:5]
# Out:
# [2022, 2022, 2022, 2022, 2022]

# %%
# adding year column to df
pass_stats['Last_Year'] = year_list
pass_stats.head()
# Out:
#    Rk          Player            School      Conf   G  Completions  Attempts  \
# 0   1   hendon hooker         Tennessee       SEC  11          229       329
# 1   2    todd centeio     James Madison  Sun Belt  10          181       284
# 2   3     c.j. stroud        Ohio State   Big Ten  12          235       355
# 3   4   kurtis rourke              Ohio       MAC  11          244       353
# 4   5  grayson mccall  Coastal Carolina  Sun Belt  10          197       285
#
#    CompletionPCT  PassYds  YardsPerAttempt  ...  Int  EfficiencyRtg  RushAtt  \
# 0           69.6     3135              9.5  ...    2          175.5      104
# 1           63.7     2697              9.5  ...    5          169.0       95
# 2           66.2     3340              9.4  ...    6          176.2       35
# 3           69.1     3257              9.2  ...    4          167.7       74
# 4           69.1     2633              9.2  ...    2          173.1       87
#
# ...

# %%
# drop categorical variables, and last_year (since we don't want to sum this one)
pass_stats1 = pass_stats.drop(columns=['Player', 'School', 'Conf', 'Rk', "Last_Year"]).copy()

# %%
# grouping stats by player
pass_stats_grouped = pass_stats1.groupby(by='PK1').sum()
pass_stats_grouped.head()
# Out:
#                            G  Completions  Attempts  CompletionPCT  PassYds  \
# PK1
# a.j. doyle+Massachusetts  11          128       235           54.5     1274
# a.j. erdely+UAB           13          205       338           60.7     2331
# a.j. feeley+Oregon        10          136       259           52.5     1951
# a.j. mccarron+Alabama     40          656       978          201.3     8630
# a.j. suggs+Georgia Tech   13          208       363           57.3     2242
#
#                           YardsPerAttempt  AdjustedYardsPerAttempt  \
# PK1
# a.j. doyle+Massachusetts              5.4                      3.8
# a.j. erdely+UAB                       6.9                      7.3
# a.j. feeley+Oregon                    7.5                      7.6
# a.j. mccarron+Alabama                26.4                     28.9
# a.j. suggs+Georgia Tech               6.2                      5.0
#
#                           PassingTDs  Int  EfficiencyRtg  RushAtt  RushYds  \
# PK1
# ...

# %%
# adding a yards per game column
pass_stats_grouped['YPG'] = pass_stats_grouped['PassYds'] / pass_stats_grouped['G']
pass_stats_grouped['AdjustedYardsPerAttempt'] = pass_stats_grouped['AdjustedYds'] / pass_stats_grouped['Attempts']
pass_stats_grouped['YardsPerAttempt'] = pass_stats_grouped['PassYds'] / pass_stats_grouped['Attempts']
pass_stats_grouped = pass_stats_grouped.merge(pass_stats.drop_duplicates(subset=['PK1'])[['PK1', 'Last_Year', 'Conf']], on='PK1', how='left')
pass_stats_grouped['year_drafted'] = pass_stats_grouped['Last_Year']+1
pass_stats_grouped['year_drafted'] = pass_stats_grouped['year_drafted'].astype(str)
pass_stats_grouped.head()
# Out:
#                         PK1   G  Completions  Attempts  CompletionPCT  \
# 0  a.j. doyle+Massachusetts  11          128       235           54.5
# 1           a.j. erdely+UAB  13          205       338           60.7
# 2        a.j. feeley+Oregon  10          136       259           52.5
# 3     a.j. mccarron+Alabama  40          656       978          201.3
# 4   a.j. suggs+Georgia Tech  13          208       363           57.3
#
#    PassYds  YardsPerAttempt  AdjustedYardsPerAttempt  PassingTDs  Int  ...  \
# 0     1274         5.421277                 3.800000           6   11  ...
# 1     2331         6.896450                 7.300000          16    4  ...
# 2     1951         7.532819                 7.600000          14    6  ...
# 3     8630         8.824131                 9.617996          74   15  ...
# 4     2242         6.176309                 5.000000          12   15  ...
#
#    RushAtt  RushYds  RushAvg  RushTD  Year  AdjustedYds         YPG  \
# ...

# %%
pass_stats_grouped['PK'] = pass_stats_grouped['PK1'].str.split("+").str[0]+"+"+pass_stats_grouped['year_drafted']
pass_stats_grouped.head()
# Out:
#                         PK1   G  Completions  Attempts  CompletionPCT  \
# 0  a.j. doyle+Massachusetts  11          128       235           54.5
# 1           a.j. erdely+UAB  13          205       338           60.7
# 2        a.j. feeley+Oregon  10          136       259           52.5
# 3     a.j. mccarron+Alabama  40          656       978          201.3
# 4   a.j. suggs+Georgia Tech  13          208       363           57.3
#
#    PassYds  YardsPerAttempt  AdjustedYardsPerAttempt  PassingTDs  Int  ...  \
# 0     1274         5.421277                 3.800000           6   11  ...
# 1     2331         6.896450                 7.300000          16    4  ...
# 2     1951         7.532819                 7.600000          14    6  ...
# 3     8630         8.824131                 9.617996          74   15  ...
# 4     2242         6.176309                 5.000000          12   15  ...
#
#    RushYds  RushAvg  RushTD  Year  AdjustedYds         YPG  Last_Year    Conf  \
# ...

# %%
def combine_draft_and_combine(df1, df2):
    """Function for combining the draft order and combine data
    df1 refers to the draft dataframe, df2 is combine. This function only works for 2000-present"""
    df1 = df1[df1['Position']=='QB']
    a = df1.merge(df2, how='left', on='Pick')
    a = a.drop(columns=['Player_y', 'Position_y','School_y','Year_y', 'Round_y'])
    a.columns = ['Round', 'Pick', 'Team', 'Player', 'Position', 'Age', 'School', 'Year', 'Weight', '40 Time', 'Vertical Jump', '3 Cone', 'Shuttle', 'Height (in)']
    a['Year'] = a['Year'].astype(str)
    a['PK'] = a['Player'] + "+" + a['Year']
    a['PK'] = a['PK'].str.lower()
    return a

# %%
def combine_draft_and_combine90s(df1, df2):
    df1 = df1[df1['Position']=='QB'].copy()
    df1['Year'] = df1['Year'].astype(str)
    df1['PK'] = df1['Player'].str.lower()+"+"+df1['Year']
    df1['Year'] = df1['Year'].astype(int)
    a = df1.merge(df2, how='left', on='PK')
    a = a.drop(columns=['Player_y', 'Position_y','School_y','Year_y'])
    a.columns = ['Round', 'Pick', 'Team', 'Player', 'Position', 'Age', 'School', 'Year', 'PK', 'Weight', '40 Time', 'Vertical Jump', '3 Cone', 'Shuttle', 'Height (in)']
    a = a[['Round', 'Pick', 'Team', 'Player', 'Position', 'Age', 'School', 'Year', 'Weight', '40 Time', 'Vertical Jump', '3 Cone', 'Shuttle', 'Height (in)', 'PK']]
    return a

# %%
def get_final_df(df1, df2):
    a = df1.merge(df2, on='PK', how='left')
    return a

# %%
pass_stats_grouped.head()
# Out:
#                         PK1   G  Completions  Attempts  CompletionPCT  \
# 0  a.j. doyle+Massachusetts  11          128       235           54.5
# 1           a.j. erdely+UAB  13          205       338           60.7
# 2        a.j. feeley+Oregon  10          136       259           52.5
# 3     a.j. mccarron+Alabama  40          656       978          201.3
# 4   a.j. suggs+Georgia Tech  13          208       363           57.3
#
#    PassYds  YardsPerAttempt  AdjustedYardsPerAttempt  PassingTDs  Int  ...  \
# 0     1274         5.421277                 3.800000           6   11  ...
# 1     2331         6.896450                 7.300000          16    4  ...
# 2     1951         7.532819                 7.600000          14    6  ...
# 3     8630         8.824131                 9.617996          74   15  ...
# 4     2242         6.176309                 5.000000          12   15  ...
#
#    RushYds  RushAvg  RushTD  Year  AdjustedYds         YPG  Last_Year    Conf  \
# ...

# %%
final_2022 = get_final_df(combine_draft_and_combine(draft_2022, clean_combine(combine_2022, "QB")), pass_stats_grouped)
final_2021 = get_final_df(combine_draft_and_combine(draft_2021, clean_combine(combine_2021, "QB")), pass_stats_grouped)
final_2020 = get_final_df(combine_draft_and_combine(draft_2020, clean_combine(combine_2020, "QB")), pass_stats_grouped)
final_2019 = get_final_df(combine_draft_and_combine(draft_2019, clean_combine(combine_2019, "QB")), pass_stats_grouped)
final_2018 = get_final_df(combine_draft_and_combine(draft_2018, clean_combine(combine_2018, "QB")), pass_stats_grouped)
final_2017 = get_final_df(combine_draft_and_combine(draft_2017, clean_combine(combine_2017, "QB")), pass_stats_grouped)
final_2016 = get_final_df(combine_draft_and_combine(draft_2016, clean_combine(combine_2016, "QB")), pass_stats_grouped)
final_2015 = get_final_df(combine_draft_and_combine(draft_2015, clean_combine(combine_2015, "QB")), pass_stats_grouped)
final_2014 = get_final_df(combine_draft_and_combine(draft_2014, clean_combine(combine_2014, "QB")), pass_stats_grouped)
final_2013 = get_final_df(combine_draft_and_combine(draft_2013, clean_combine(combine_2013, "QB")), pass_stats_grouped)
final_2012 = get_final_df(combine_draft_and_combine(draft_2012, clean_combine(combine_2012, "QB")), pass_stats_grouped)
final_2011 = get_final_df(combine_draft_and_combine(draft_2011, clean_combine(combine_2011, "QB")), pass_stats_grouped)
final_2010 = get_final_df(combine_draft_and_combine(draft_2010, clean_combine(combine_2010, "QB")), pass_stats_grouped)
final_2009 = get_final_df(combine_draft_and_combine(draft_2009, clean_combine(combine_2009, "QB")), pass_stats_grouped)
final_2008 = get_final_df(combine_draft_and_combine(draft_2008, clean_combine(combine_2008, "QB")), pass_stats_grouped)
final_2007 = get_final_df(combine_draft_and_combine(draft_2007, clean_combine(combine_2007, "QB")), pass_stats_grouped)
final_2006 = get_final_df(combine_draft_and_combine(draft_2006, clean_combine(combine_2006, "QB")), pass_stats_grouped)
final_2005 = get_final_df(combine_draft_and_combine(draft_2005, clean_combine(combine_2005, "QB")), pass_stats_grouped)
final_2004 = get_final_df(combine_draft_and_combine(draft_2004, clean_combine(combine_2004, "QB")), pass_stats_grouped)
final_2003 = get_final_df(combine_draft_and_combine(draft_2003, clean_combine(combine_2003, "QB")), pass_stats_grouped)
final_2002 = get_final_df(combine_draft_and_combine(draft_2002, clean_combine(combine_2002, "QB")), pass_stats_grouped)
final_2001 = get_final_df(combine_draft_and_combine(draft_2001, clean_combine(combine_2001, "QB")), pass_stats_grouped)
final_2000 = get_final_df(combine_draft_and_combine(draft_2000, clean_combine(combine_2000, "QB")), pass_stats_grouped)
final_1999 = get_final_df(combine_draft_and_combine90s(draft_1999, clean_combine90s(combine_1999, "QB")), pass_stats_grouped)
final_1998 = get_final_df(combine_draft_and_combine90s(draft_1998, clean_combine90s(combine_1998, "QB")), pass_stats_grouped)
final_1997 = get_final_df(combine_draft_and_combine90s(draft_1997, clean_combine90s(combine_1997, "QB")), pass_stats_grouped)
final_1996 = get_final_df(combine_draft_and_combine90s(draft_1996, clean_combine90s(combine_1996, "QB")), pass_stats_grouped)
final_1995 = get_final_df(combine_draft_and_combine90s(draft_1995, clean_combine90s(combine_1995, "QB")), pass_stats_grouped)
final_1994 = get_final_df(combine_draft_and_combine90s(draft_1994, clean_combine90s(combine_1994, "QB")), pass_stats_grouped)
final_1993 = get_final_df(combine_draft_and_combine90s(draft_1993, clean_combine90s(combine_1993, "QB")), pass_stats_grouped)

# %%
# reading in data for response variable
points_1993 = pd.read_csv('yearly/1993.csv')
points_1994 = pd.read_csv('yearly/1994.csv')
points_1995 = pd.read_csv('yearly/1995.csv')
points_1996 = pd.read_csv('yearly/1996.csv')
points_1997 = pd.read_csv('yearly/1997.csv')
points_1998 = pd.read_csv('yearly/1998.csv')
points_1999 = pd.read_csv('yearly/1999.csv')
points_2000 = pd.read_csv('yearly/2000.csv')
points_2001 = pd.read_csv('yearly/2001.csv')
points_2002 = pd.read_csv('yearly/2002.csv')
points_2003 = pd.read_csv('yearly/2003.csv')
points_2004 = pd.read_csv('yearly/2004.csv')
points_2005 = pd.read_csv('yearly/2005.csv')
points_2006 = pd.read_csv('yearly/2006.csv')
points_2007 = pd.read_csv('yearly/2007.csv')
points_2008 = pd.read_csv('yearly/2008.csv')
points_2009 = pd.read_csv('yearly/2009.csv')
points_2010 = pd.read_csv('yearly/2010.csv')
points_2011 = pd.read_csv('yearly/2011.csv')
points_2012 = pd.read_csv('yearly/2012.csv')
points_2013 = pd.read_csv('yearly/2013.csv')
points_2014 = pd.read_csv('yearly/2014.csv')
points_2015 = pd.read_csv('yearly/2015.csv')
points_2016 = pd.read_csv('yearly/2016.csv')
points_2017 = pd.read_csv('yearly/2017.csv')
points_2018 = pd.read_csv('yearly/2018.csv')
points_2019 = pd.read_csv('yearly/2019.csv')
points_2020 = pd.read_csv('yearly/2020.csv')
points_2021 = pd.read_csv('yearly/2021.csv')

points_1993['Year'] = 1993
points_1994['Year'] = 1994
points_1995['Year'] = 1995
points_1996['Year'] = 1996
points_1997['Year'] = 1997
points_1998['Year'] = 1998
points_1999['Year'] = 1999
points_2000['Year'] = 2000
points_2001['Year'] = 2001
points_2002['Year'] = 2002
points_2003['Year'] = 2003
points_2004['Year'] = 2004
points_2005['Year'] = 2005
points_2006['Year'] = 2006
points_2007['Year'] = 2007
points_2008['Year'] = 2008
points_2009['Year'] = 2009
points_2010['Year'] = 2010
points_2011['Year'] = 2011
points_2012['Year'] = 2012
points_2013['Year'] = 2013
points_2014['Year'] = 2014
points_2015['Year'] = 2015
points_2016['Year'] = 2016
points_2017['Year'] = 2017
points_2018['Year'] = 2018
points_2019['Year'] = 2019
points_2020['Year'] = 2020
points_2021['Year'] = 2021

# %%
# concatenating dfs
points_full = pd.concat([points_1993, points_1994, points_1995, points_1996, points_1997, points_1998, points_1999, points_2000, points_2001, points_2002, points_2003, points_2004, points_2005, points_2006, points_2007, points_2008, points_2009,
                        points_2010, points_2011, points_2012, points_2013, points_2014, points_2015, points_2016, points_2017, points_2018, points_2019, points_2020, points_2021])

# removing characters
points_full['Player'] = points_full['Player'].str.replace("*","")
points_full['Player'] = points_full['Player'].str.replace("+","")

# creating primary key

# creating response variable
points_full['PPRPoints'] = points_full['Rec'] + (points_full['PassingYds']*.04) + (points_full['PassingTD']*4) + (points_full['RushingTD']*6) + (points_full['ReceivingTD']*6) + (points_full['RushingYds']*.1) + (points_full['ReceivingYds']*.1) - (points_full['FumblesLost']*2) - (points_full['Int']*2)

# %%
points_full_qb = points_full[points_full['Pos']=='QB'].copy()
points_full_qb.head()
# Out:
#     Unnamed: 0          Player   Tm Pos   Age     G    GS  Tgt  Rec  \
# 2          2.0     Steve Young  SFO  QB  32.0  16.0  16.0  2.0  2.0
# 8          8.0      John Elway  DEN  QB  33.0  16.0  16.0  0.0  0.0
# 23        23.0  Jeff Hostetler  RAI  QB  32.0  15.0  15.0  1.0  0.0
# 33        33.0     Warren Moon  HOU  QB  37.0  15.0  14.0  0.0  0.0
# 41        41.0  Boomer Esiason  NYJ  QB  32.0  16.0  16.0  1.0  1.0
#
#     PassingYds  ...  RushingTD  RushingAtt  ReceivingYds  ReceivingTD  \
# 2       4023.0  ...        2.0        69.0           2.0          0.0
# 8       4030.0  ...        0.0        44.0           0.0          0.0
# 23      3242.0  ...        5.0        55.0           0.0          0.0
# 33      3485.0  ...        1.0        48.0           0.0          0.0
# 41      3421.0  ...        1.0        45.0          -8.0          0.0
#
#     FantasyPoints   Int  Fumbles  FumblesLost  Year  PPRPoints
# 2          283.82  16.0      8.0          0.0  1993     299.82
# ...

# %%
points_full_qb.to_csv('qb_points_full.csv')

# %%
points_full_qb['PK'] = points_full_qb['Player'] + "+" + points_full_qb['Tm']
points_full_qb = points_full_qb[points_full_qb['G']>3]

# %%
def get_fy(pk):
    """Function to determine the first year a player was in the NFL"""
    a = points_full_qb.loc[points_full_qb['PK']==f'{pk}']
    b = min(a['Year'])
    return b

# %%
pk_list = []
for index, row in points_full_qb.iterrows():
    pk_list.append(row['PK'])

# %%
# creating a list of the first year each player played 
year_list = []
for x in pk_list:
    year_list.append(str(get_fy(f"{x}")))

# %%
points_full_qb = points_full_qb.copy()
points_full_qb['first_year'] = year_list
points_full_qb.head()
points_full_qb['PK2'] = points_full_qb['Player'].str.lower()+"+"+points_full_qb['first_year']
points_full_qb_grouped = points_full_qb.groupby('PK2').sum()
points_full_qb_grouped['PPG'] = points_full_qb_grouped['PPRPoints']/points_full_qb_grouped['G']
points_full_qb_grouped['PK'] = points_full_qb_grouped.index
points_full_qb_grouped[points_full_qb_grouped['PK']=="joe burrow+2020"]
# Out:
#                  Unnamed: 0   Age     G    GS  Tgt  Rec  PassingYds  \
# PK2
# joe burrow+2020        28.0  49.0  26.0  26.0  0.0  0.0      7299.0
#
#                  PassingTD  PassingAtt  RushingYds  ...  ReceivingYds  \
# PK2                                                 ...
# joe burrow+2020       47.0       924.0       260.0  ...           0.0
#
#                  ReceivingTD  FantasyPoints   Int  Fumbles  FumblesLost  Year  \
# PK2
# joe burrow+2020          0.0          488.0  19.0     14.0          6.0  4041
#
#                  PPRPoints        PPG               PK
# PK2
# joe burrow+2020     485.96  18.690769  joe burrow+2020
#
# [1 rows x 22 columns]

# %%
# calculating quantiles for response variable
q90 = points_full_qb_grouped.PPG.quantile(.90)
q75 = points_full_qb_grouped.PPG.quantile(.75)
q50 = points_full_qb_grouped.PPG.quantile(.50)
q25 = points_full_qb_grouped.PPG.quantile(.25)
q90
# Out:
# 14.781081081081084

# %%
# creating response column. Players in the top 10% are considered stars, top 25% good starters, top 50% borderline starters, and bottom 25% not playing
response = []
for x in points_full_qb_grouped['PPG']:
    if x >= q90:
        response.append(1)
    elif x >= q75:
        response.append(2)
    elif x >= q25:
        response.append(3)
    else:
        response.append(4)

# %%
# setting response column
points_full_qb_grouped['response'] = response

# %%
# saving df
points_full_qb_grouped.to_csv('qbpoints.csv')

# %%
#checking info
points_full_qb_grouped[points_full_qb_grouped['PK'].str.contains('manning')]
# Out:
#                      Unnamed: 0    Age      G     GS  Tgt  Rec  PassingYds  \
# PK2
# eli manning+2004         1389.0  488.0  236.0  234.0  0.0  0.0     57023.0
# peyton manning+1998       329.0  364.0  208.0  208.0  1.0  1.0     54828.0
# peyton manning+2012       188.0  150.0   58.0   57.0  0.0  0.0     17112.0
#
#                      PassingTD  PassingAtt  RushingYds  ...  ReceivingTD  \
# PK2                                                     ...
# eli manning+2004         366.0      8119.0       567.0  ...          0.0
# peyton manning+1998      399.0      7210.0       722.0  ...          0.0
# peyton manning+2012      140.0      2170.0       -55.0  ...          0.0
#
#                      FantasyPoints    Int  Fumbles  FumblesLost   Year  \
# PK2
# eli manning+2004           3241.62  244.0    125.0         57.0  32184
# peyton manning+1998        3530.12  198.0     57.0         19.0  26052
# peyton manning+2012        1118.98   53.0     20.0         10.0   8054
#
# ...

# %%
# creating final features df
final_features = pd.concat([final_1993, final_1994, final_1995, final_1996, final_1997, final_1998, final_1999, final_2000, final_2001, final_2002, final_2003, final_2004, final_2005, final_2006,
                           final_2007, final_2008, final_2009, final_2010, final_2010, final_2011, final_2012, final_2013, final_2014, final_2015, final_2016, final_2017, final_2018, final_2019, final_2020,final_2021, final_2022])

# %%
# creating df for use in next step
qb_final = final_features.merge(points_full_qb_grouped[['PK', 'response']], how='left', on='PK')
qb_final.shape
# Out:
# (363, 37)

# %%
# saving df
qb_final.to_csv('qb_final.csv')
